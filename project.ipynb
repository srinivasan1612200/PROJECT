# %%
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as pt

# %%
# %matplotlib inline

# %%
ram=pd.read_csv("solarprediction.csv")

# %%
ram
# Out:
#          UNIXTime                   Data      Time  Radiation  Temperature  \
# 0      1475229326  9/29/2016 12:00:00 AM  23:55:26       1.21           48
# 1      1475229023  9/29/2016 12:00:00 AM  23:50:23       1.21           48
# 2      1475228726  9/29/2016 12:00:00 AM  23:45:26       1.23           48
# 3      1475228421  9/29/2016 12:00:00 AM  23:40:21       1.21           48
# 4      1475228124  9/29/2016 12:00:00 AM  23:35:24       1.17           48
# ...           ...                    ...       ...        ...          ...
# 32681  1480587604  12/1/2016 12:00:00 AM  00:20:04       1.22           44
# 32682  1480587301  12/1/2016 12:00:00 AM  00:15:01       1.17           44
# 32683  1480587001  12/1/2016 12:00:00 AM  00:10:01       1.20           44
# 32684  1480586702  12/1/2016 12:00:00 AM  00:05:02       1.23           44
# 32685  1480586402  12/1/2016 12:00:00 AM  00:00:02       1.20           44
#
# ...

# %%
newdataset=ram.drop(['UNIXTime','Data','Time','Radiation','Pressure','WindDirection(Degrees)','Speed','TimeSunRise','TimeSunSet'],axis=1)

# %%
x=newdataset.iloc[:,0].values.reshape(-1,1)
y=newdataset.iloc[:,1].values.reshape(-1,1)

# %%
x
# Out:
# array([[48],
#        [48],
#        [48],
#        ...,
#        [44],
#        [44],
#        [44]], dtype=int64)

# %%
y
# Out:
# array([[ 59],
#        [ 58],
#        [ 57],
#        ...,
#        [102],
#        [101],
#        [101]], dtype=int64)

# %%
pt.scatter(x,y)
pt.xlabel('Temperature')
pt.ylabel('Humidity')
pt.title('linear reg')
pt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,train_size=0.8,random_state=0)

# %%
X_train.shape
# Out:
# (26148, 1)

# %%
X_test.shape
# Out:
# (6538, 1)

# %%
Y_train
# Out:
# array([[ 49],
#        [ 91],
#        [101],
#        ...,
#        [ 30],
#        [101],
#        [ 50]], dtype=int64)

# %%
Y_test
# Out:
# array([[0.71],
#        [0.7 ],
#        [0.79],
#        [0.73],
#        [0.72],
#        [0.48],
#        [0.77],
#        [0.71],
#        [0.9 ],
#        [0.94],
#        [0.58],
#        [0.89],
#        [0.72],
#        [0.57],
#        [0.78],
#        [0.42],
#        [0.64],
#        [0.84],
#        [0.63],
#        [0.72],
#        [0.9 ],
#        [0.83],
#        [0.57],
#        [0.47],
#        [0.85],
#        [0.67],
#        [0.44],
#        [0.54],
#        [0.92],
#        [0.62],
#        [0.68],
#        [0.73],
#        [0.73],
#        [0.61],
#        [0.55],
#        [0.74],
#        [0.64],
#        [0.89],
#        [0.73],
#        [0.95],
#        [0.71],
#        [0.72],
#        [0.75],
#        [0.76],
#        [0.86],
#        [0.7 ],
#        [0.39],
#        [0.79],
#        [0.61],
#        [0.64],
#        [0.71],
#        [0.8 ],
#        [0.61],
#        [0.89],
#        [0.68],
#        [0.79],
#        [0.78],
#        [0.52],
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_predict=lm.predict(X_test)

# %%
y_predict
# Out:
# array([[0.64740806],
#        [0.63728454],
#        [0.81950792],
#        [0.6170375 ],
#        [0.71827271],
#        [0.64740806],
#        [0.67777862],
#        [0.67777862],
#        [0.88024905],
#        [0.87012553],
#        [0.55629637],
#        [0.89037257],
#        [0.75876679],
#        [0.57654341],
#        [0.83975496],
#        [0.6676551 ],
#        [0.67777862],
#        [0.84987848],
#        [0.70814919],
#        [0.68790215],
#        [0.84987848],
#        [0.82963144],
#        [0.56641989],
#        [0.50567876],
#        [0.75876679],
#        [0.56641989],
#        [0.51580228],
#        [0.69802567],
#        [0.92074313],
#        [0.69802567],
#        [0.67777862],
#        [0.78913736],
#        [0.67777862],
#        [0.51580228],
#        [0.8093844 ],
#        [0.82963144],
#        [0.73851975],
#        [0.78913736],
#        [0.62716102],
#        [0.89037257],
#        [0.77901384],
#        [0.69802567],
#        [0.76889032],
# ...

# %%
nan=pd.DataFrame(X_test,columns=['Temperature'])

# %%
nan
# Out:
#       Temperature
# 0              61
# 1              48
# 2              60
# 3              44
# 4              49
# ...           ...
# 6533           43
# 6534           48
# 6535           46
# 6536           52
# 6537           56
#
# [6538 rows x 1 columns]

# %%
nan['PRDATA']=y_predict

# %%
nan
# Out:
#       Temperature     PRDATA
# 0              61  63.039873
# 1              48  78.821146
# 2              60  64.253817
# 3              44  83.676922
# 4              49  77.607202
# ...           ...        ...
# 6533           43  84.890866
# 6534           48  78.821146
# 6535           46  81.249034
# 6536           52  73.965369
# 6537           56  69.109593
#
# [6538 rows x 2 columns]

# %%
pt.scatter(x,y,color='red')
pt.plot(X_test,y_predict,color='blue')
pt.xlabel('Temperature')
pt.ylabel('Humidity')
pt.title('linear reg')
pt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mean_squared_error(Y_test,y_predict)
# Out:
# 631.1723776018077

# %%
mean_absolute_error(Y_test,y_predict)
# Out:
# 21.27062180050051

# %%
r2_score(Y_test,y_predict)
# Out:
# 0.07067557294896254

# %%
lm.score(X_test,Y_test)
# Out:
# 0.07067557294896254

# %%
nan.to_csv("C:\\Users\\ADMIN\\Documents\\project1.csv")
